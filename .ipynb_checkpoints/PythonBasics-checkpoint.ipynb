# %%
type(-123)
# Out:
# int

# %%
type(1.3)
# Out:
# float

# %%
type("shdfkhakdsfhalsd89945hskdhfk")
# Out:
# str

# %%
a = "jhdkfjks"
b = "uhuf"

id(a)
# Out:
# 1734187838256

# %%
float(4)
# Out:
# 4.0

# %%
int(4.0)
# Out:
# 4

# %%
float("kjfdkhskf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 float("kjfdkhskf")
#
# ValueError: could not convert string to float: 'kjfdkhskf'

# %%
str(4.0)
# Out:
# '4.0'

# %%
3 > 2
# Out:
# True

# %%
print("Hello world")
# Out:
# Hello world

# %%
z = "Hello world"
z = "Hi"

# %%
print(z)
# Out:
# Hi

# %%
type("hdfj")
# Out:
# str

# %%
type(4)
# Out:
# int

# %%
type(5.3)
# Out:
# float

# %%
type(3==2)
# Out:
# bool

# %%
print

# %%
a = 3
a += 4
print(a)
# Out:
# 7

# %%
z = 9
z *= 3

print(z)
# Out:
# 27

# %%
a = {2, 4, 222}

a[0] = 7

print(a[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 3
#       1 a = {2, 4, 222}
# ----> 3 a[0] = 7
#       5 print(a[0])
#
# TypeError: 'set' object does not support item assignment

# %%
print(range(4))
# Out:
# range(0, 4)

# %%
a = "Hallihallo"

a[0:5]

for k in range(4):
    print(k)
# Out:
# 0
# 1
# 2
# 3

# %%
for b in range(4):
    print("Hi")
# Out:
# Hi
# Hi
# Hi
# Hi

# %%
import numpy as np

np.linspace
# Out:
# 1
