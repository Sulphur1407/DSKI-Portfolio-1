# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
## Durchschnittliches Inflight Wifi Rating pro Reiseart vergleichen
wifi_avg_by_travel = df.groupby('Type of Travel')['Inflight wifi service'].mean()

print("Durchschnittliches Inflight Wifi Rating:")
print(wifi_avg_by_travel)
# Out:
# Durchschnittliches Inflight Wifi Rating:
# Type of Travel
# Business travel    2.823292
# Personal Travel    2.521691
# Name: Inflight wifi service, dtype: float64
